# %%
from basic_image_eda import BasicImageEDA

data_dir = "./dataset_with_aug"
BasicImageEDA.explore(data_dir)

# or

extensions = ['png', 'jpg', 'jpeg']
threads = 0
dimension_plot = True
channel_hist = True
nonzero = False
hw_division_factor = 1.0

BasicImageEDA.explore(data_dir, extensions, threads, dimension_plot, channel_hist, nonzero, hw_division_factor)
# Out:
# found 1803 images.
# Using 12 threads. (max:12)
# 100%|██████████| 1803/1803 [00:02<00:00, 837.06it/s]
# *--------------------------------------------------------------------------------------*
# number of images                         |  1803
#
# dtype                                    |  uint8
# channels                                 |  [3]
# extensions                               |  ['png']
#
# min height                               |  128
# max height                               |  128
# mean height                              |  128.0
# median height                            |  128
#
# min width                                |  128
# max width                                |  128
# mean width                               |  128.0
# median width                             |  128
#
# mean height/width ratio                  |  1.0
# median height/width ratio                |  1.0
# recommended input size(by mean)          |  [128 128] (h x w, multiples of 8)
# recommended input size(by mean)          |  [128 128] (h x w, multiples of 16)
# recommended input size(by mean)          |  [128 128] (h x w, multiples of 32)
#
# channel mean(0~1)                        |  [0.505133   0.29178333 0.16570434]
# channel std(0~1)                         |  [0.29568654 0.18084215 0.11734849]
# *--------------------------------------------------------------------------------------*
# eda ended in 00 hours 00 minutes 02 seconds
#
# found 1803 images.
# Using 12 threads. (max:12)
# 100%|██████████| 1803/1803 [00:02<00:00, 694.76it/s]
# *--------------------------------------------------------------------------------------*
# number of images                         |  1803
#
# dtype                                    |  uint8
# channels                                 |  [3]
# extensions                               |  ['png']
#
# min height                               |  128
# max height                               |  128
# mean height                              |  128.0
# median height                            |  128
#
# min width                                |  128
# max width                                |  128
# mean width                               |  128.0
# median width                             |  128
#
# mean height/width ratio                  |  1.0
# median height/width ratio                |  1.0
# recommended input size(by mean)          |  [128 128] (h x w, multiples of 8)
# recommended input size(by mean)          |  [128 128] (h x w, multiples of 16)
# recommended input size(by mean)          |  [128 128] (h x w, multiples of 32)
#
# channel mean(0~1)                        |  [0.505133   0.29178336 0.16570435]
# channel std(0~1)                         |  [0.2956865  0.18084207 0.11734846]
# *--------------------------------------------------------------------------------------*
# eda ended in 00 hours 00 minutes 03 seconds
# {'dtype': 'uint8',
#  'channels': [3],
#  'extensions': ['png'],
#  'min_h': 128,
#  'max_h': 128,
#  'mean_h': 128.0,
#  'median_h': 128,
#  'min_w': 128,
#  'max_w': 128,
#  'mean_w': 128.0,
#  'median_w': 128,
#  'mean_hw_ratio': 1.0,
#  'median_hw_ratio': 1.0,
#  'rec_hw_size_8': array([128, 128]),
#  'rec_hw_size_16': array([128, 128]),
#  'rec_hw_size_32': array([128, 128]),
#  'mean': array([0.505133  , 0.29178336, 0.16570435], dtype=float32),
#  'std': array([0.2956865 , 0.18084207, 0.11734846], dtype=float32)}
