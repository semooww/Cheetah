# %%
from basic_image_eda import BasicImageEDA

data_dir = "../dataset"
#BasicImageEDA.explore(data_dir)

# or

extensions = ['png', 'jpg', 'jpeg']
threads = 0
dimension_plot = True
channel_hist = True
nonzero = False
hw_division_factor = 1.0

BasicImageEDA.explore(data_dir, extensions, threads, dimension_plot, channel_hist, nonzero, hw_division_factor)
# Out:
# found 601 images.
# Using 12 threads. (max:12)
# 100%|██████████| 601/601 [02:41<00:00,  3.73it/s]
# *--------------------------------------------------------------------------------------*
# number of images                         |  601
#
# dtype                                    |  uint8
# channels                                 |  [3]
# extensions                               |  ['png']
#
# min height                               |  1224
# max height                               |  1728
# mean height                              |  1669.2179700499169
# median height                            |  1728
#
# min width                                |  1848
# max width                                |  2592
# mean width                               |  2508.8319467554074
# median width                             |  2592
#
# mean height/width ratio                  |  0.6653367006939876
# median height/width ratio                |  0.6666666666666666
# recommended input size(by mean)          |  [1672 2512] (h x w, multiples of 8)
# recommended input size(by mean)          |  [1664 2512] (h x w, multiples of 16)
# recommended input size(by mean)          |  [1664 2496] (h x w, multiples of 32)
#
# channel mean(0~1)                        |  [0.30487016 0.18201233 0.10830643]
# channel std(0~1)                         |  [0.33358595 0.2029888  0.12538321]
# *--------------------------------------------------------------------------------------*
# eda ended in 00 hours 02 minutes 42 seconds
# {'dtype': 'uint8',
#  'channels': [3],
#  'extensions': ['png'],
#  'min_h': 1224,
#  'max_h': 1728,
#  'mean_h': 1669.2179700499169,
#  'median_h': 1728,
#  'min_w': 1848,
#  'max_w': 2592,
#  'mean_w': 2508.8319467554074,
#  'median_w': 2592,
#  'mean_hw_ratio': 0.6653367006939876,
#  'median_hw_ratio': 0.6666666666666666,
#  'rec_hw_size_8': array([1672, 2512]),
#  'rec_hw_size_16': array([1664, 2512]),
#  'rec_hw_size_32': array([1664, 2496]),
#  'mean': array([0.30487016, 0.18201233, 0.10830643], dtype=float32),
#  'std': array([0.33358595, 0.2029888 , 0.12538321], dtype=float32)}
